# %%
from module import *

# %%
model = absenteeism_model('model', 'scaler')
# Out:
# /Users/sarathchandrikak/opt/anaconda3/envs/mysqlconnect/lib/python3.6/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LogisticRegression from version 0.19.1 when using version 0.22. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /Users/sarathchandrikak/opt/anaconda3/envs/mysqlconnect/lib/python3.6/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.19.1 when using version 0.22. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
model.load_and_clean_data('Absenteeism_new_data.csv')

# %%
model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0          0       0.0         0         1            6
# 1          1       0.0         0         0            6
# 2          0       0.0         0         1            6
# 3          0       0.0         0         1            6
# 4          1       0.0         0         0            6
# 5          1       0.0         0         0            6
# 6          1       0.0         0         0            6
# 7          0       0.0         0         1            6
# 8          0       0.0         0         1            6
# 9          1       0.0         0         0            6
# 10         0       0.0         0         1            6
# 11         0       0.0         1         0            6
# 12         0       0.0         1         0            6
# 13         0       0.0         0         1            6
# 14         0       0.0         0         0            6
# 15         0       0.0         0         0            6
# ...

# %%
df_output = model.predicted_outputs()

# %%
df_output.to_csv('out.csv')

# %%
pip install scikit-learn==0.22
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pymysql

# %%
import pymysql

# %%
conn = pymysql.connect(database = 'predicted_outputs', user ='root', password= 'pass123')

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT * FROM predicted_outputs;")
# Out:
# 80

# %%
insert_query = "INSERT INTO predicted_outputs VALUES"

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES'

# %%
df_output.columns.values
# Out:
# array(['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4', 'Month Value',
#        'Transportation Expense', 'Age', 'Body Mass Index', 'Education',
#        'Children', 'Pet', 'Probability', 'Prediction'], dtype=object)

# %%
df_output.shape
# Out:
# (40, 13)

# %%
for i in range(df_output.shape[0]):
    insert_query += '('
    for j in range(df_output.shape[1]):
        insert_query += str(df_output[df_output.columns.values[j]][i]) + ', '
        
    insert_query = insert_query[:-2] + ' ), '

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1227992624349432, 0 ), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8733923470447209, 1 ), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.26830495460343223, 0 ), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.1963853143922252, 0 ), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7235017225544896, 1 ), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7168905020985188, 1 ), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.5705238370679658, 1 ), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1227992624349432, 0 ), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.13411805408968352, 0 ), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5250065611752316, 1 ), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.45499802072862455, 0 ), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6447416367376194, 1 ), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.35110766120784753, 0 ), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1227992624349432, 0 ), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.09653
# ...

# %%
insert_query = insert_query[:-2] + ';'

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1227992624349432, 0 ), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8733923470447209, 1 ), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.26830495460343223, 0 ), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.1963853143922252, 0 ), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.7235017225544896, 1 ), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.7168905020985188, 1 ), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.5705238370679658, 1 ), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1227992624349432, 0 ), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.13411805408968352, 0 ), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5250065611752316, 1 ), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.45499802072862455, 0 ), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6447416367376194, 1 ), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.35110766120784753, 0 ), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.1227992624349432, 0 ), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.09653
# ...

# %%
cursor.execute(insert_query)
# Out:
# 40

# %%
conn.commit()

# %%
conn.close()
